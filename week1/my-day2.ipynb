# %%
import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display

# %%
OLLAMA_API = "http://localhost:11434/api/chat"
HEADERS = { "Content-Type": "application/json" }
MODEL = "llama3.2"

# %%
messages = [
  {"role": "user", "content": "Describe some of the business applications of Generative AI"}
]

# %%
payload = {
  "model": MODEL,
  "messages": messages,
  "stream": False
}

# %%
response = requests.post(OLLAMA_API, json=payload, headers=HEADERS)
print(response.json()['message']['content'])
# Out:
# Generative AI has numerous business applications across various industries. Here are some examples:
#
# 1. **Content Creation**: Generative AI can generate high-quality content such as articles, social media posts, product descriptions, and more. This can help businesses save time and money on content creation while maintaining a consistent tone and style.
# 2. **Marketing Automation**: Generative AI can be used to automate marketing campaigns by generating personalized emails, ads, and promotions based on customer data and behavior.
# 3. **Product Design**: Generative AI can assist in product design by generating 3D models, prototypes, and designs for new products. This can help businesses reduce the time and cost associated with traditional product design methods.
# 4. **Customer Service**: Generative AI-powered chatbots can provide 24/7 customer support, answering common questions, and helping customers with basic queries.
# 5. **Data Analysis**: Generative AI can be used to analyze large datasets and generate insights, predictions, and forecasts, helping businesses make data-driven decisions.
# 6. **Image and Video Generation**: Generative AI can generate high-quality images and videos for various applications such as advertising, social media, and e-commerce.
# 7. **Recommendation Systems**: Generative AI can be used to develop personalized recommendation systems that suggest products or services based on customer behavior and preferences.
# 8. **Financial Modeling**: Generative AI can help businesses model complex financial scenarios, predict future outcomes, and identify potential risks and opportunities.
# 9. **Supply Chain Optimization**: Generative AI can analyze supply chain data and generate insights that help businesses optimize their logistics, inventory management, and shipping routes.
# 10. **Education and Training**: Generative AI can be used to create personalized learning experiences for students, generating customized educational content, and adapting to individual learning styles.
#
# Some specific business applications of generative AI include:
#
# * **Chatbots**: Companies like Amazon, Microsoft, and IBM are using chatbots to provide customer support and answer frequently asked questions.
# * **Personalized Advertising**: Generative AI is being used to generate personalized ads that target specific customers based on their behavior, preferences, and demographics.
# * **Virtual Assistants**: Generative AI-powered virtual assistants like Google Assistant, Siri, and Alexa are being used in various industries to provide customer support, answer questions, and control smart home devices.
# * **Content Optimization**: Generative AI is being used to optimize content for search engines, generating high-quality content that ranks well on search results pages.
#
# These are just a few examples of the many business applications of generative AI. As the technology continues to evolve, we can expect to see even more innovative uses in various industries.

# %%
display(Markdown(response.json()['message']['content']))
# Out:
# Generative AI has numerous business applications across various industries. Here are some examples:
#
# 1. **Content Creation**: Generative AI can generate high-quality content such as articles, social media posts, product descriptions, and more. This can help businesses save time and money on content creation while maintaining a consistent tone and style.
# 2. **Marketing Automation**: Generative AI can be used to automate marketing campaigns by generating personalized emails, ads, and promotions based on customer data and behavior.
# 3. **Product Design**: Generative AI can assist in product design by generating 3D models, prototypes, and designs for new products. This can help businesses reduce the time and cost associated with traditional product design methods.
# 4. **Customer Service**: Generative AI-powered chatbots can provide 24/7 customer support, answering common questions, and helping customers with basic queries.
# 5. **Data Analysis**: Generative AI can be used to analyze large datasets and generate insights, predictions, and forecasts, helping businesses make data-driven decisions.
# 6. **Image and Video Generation**: Generative AI can generate high-quality images and videos for various applications such as advertising, social media, and e-commerce.
# 7. **Recommendation Systems**: Generative AI can be used to develop personalized recommendation systems that suggest products or services based on customer behavior and preferences.
# 8. **Financial Modeling**: Generative AI can help businesses model complex financial scenarios, predict future outcomes, and identify potential risks and opportunities.
# 9. **Supply Chain Optimization**: Generative AI can analyze supply chain data and generate insights that help businesses optimize their logistics, inventory management, and shipping routes.
# 10. **Education and Training**: Generative AI can be used to create personalized learning experiences for students, generating customized educational content, and adapting to individual learning styles.
#
# Some specific business applications of generative AI include:
#
# * **Chatbots**: Companies like Amazon, Microsoft, and IBM are using chatbots to provide customer support and answer frequently asked questions.
# * **Personalized Advertising**: Generative AI is being used to generate personalized ads that target specific customers based on their behavior, preferences, and demographics.
# * **Virtual Assistants**: Generative AI-powered virtual assistants like Google Assistant, Siri, and Alexa are being used in various industries to provide customer support, answer questions, and control smart home devices.
# * **Content Optimization**: Generative AI is being used to optimize content for search engines, generating high-quality content that ranks well on search results pages.
#
# These are just a few examples of the many business applications of generative AI. As the technology continues to evolve, we can expect to see even more innovative uses in various industries.

# %%
import ollama

response = ollama.chat(model=MODEL, messages=messages)
display(Markdown(response['message']['content']))
# Out:
# Generative AI has numerous business applications across various industries, including:
#
# 1. **Content Generation**: AI-powered tools can generate high-quality content such as articles, blog posts, product descriptions, and social media posts, saving time and resources for content creators.
# 2. **Marketing Automation**: Generative AI can help automate marketing campaigns by generating personalized emails, advertisements, and promotional materials based on customer data and behavior.
# 3. **Product Design and Development**: AI can assist in the design and development of new products by generating 3D models, prototypes, and user interfaces.
# 4. **Customer Service Chatbots**: Generative AI-powered chatbots can provide 24/7 support to customers, answering frequently asked questions, and helping with simple issues.
# 5. **Data Analysis and Visualization**: AI can help analyze large datasets and generate insights, visualizations, and reports, enabling data-driven decision-making.
# 6. **Personalization**: Generative AI can create personalized recommendations for customers based on their preferences, behavior, and demographics.
# 7. **Language Translation**: AI-powered tools can translate text and speech in real-time, breaking language barriers and facilitating global communication.
# 8. **Image and Video Editing**: Generative AI can generate new images, videos, and animations based on existing content, reducing the need for manual editing and post-production work.
# 9. **Music Composition and Production**: AI can assist musicians and producers in composing music, generating beats, and even creating entire tracks.
# 10. **Supply Chain Optimization**: Generative AI can analyze supply chain data and generate optimized routes, schedules, and inventory management plans to improve efficiency and reduce costs.
#
# Industry-specific applications:
#
# 1. **Healthcare**: Generative AI can help create personalized treatment plans, diagnose diseases, and develop new medical treatments.
# 2. **Finance**: AI-powered tools can generate financial reports, forecasts, and risk assessments, enabling better investment decisions.
# 3. **Education**: AI can assist in creating customized learning materials, generating adaptive assessments, and providing real-time feedback to students.
# 4. **Manufacturing**: Generative AI can design and optimize production workflows, predict maintenance needs, and improve quality control processes.
#
# These are just a few examples of the many business applications of generative AI. As the technology continues to evolve, we can expect to see even more innovative uses in various industries.

# %%
from openai import OpenAI
ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
response = ollama_via_openai.chat.completions.create(
  model=MODEL,
  messages=messages
)

display(Markdown(response.choices[0].message.content))
# Out:
# Generative AI has numerous business applications across various industries. Here are some examples:
#
# 1. **Product Design and Development**: Generative AI can be used to create new product designs, such as furniture, architecture, or consumer electronics. Companies like IKEA and Adidas have already harnessed the power of generative design to accelerate their product development process.
# 2. **Content Generation**: Generative AI can generate high-quality content, including text, images, videos, and audio. This technology is being used by companies like News Corp and The New York Times to automate content creation for social media, blogs, and websites.
# 3. **Marketing and Advertising**: Generative AI can create personalized ads, product descriptions, and social media posts that resonate with specific target audiences. Companies like Google and IBM are using generative AI to personalize customer experiences across various channels.
# 4. **Music and Audio Production**: Generative AI can generate music, sound effects, and audio post-production sounds. This technology is being used by companies like Amazon Music and YouTube to create customized music for videos and ads.
# 5. **Fashion and Luxury Goods**: Generative AI can design new fashion collections, accessories, and product packaging. Companies like Ralph Lauren and Burberry are using generative design to accelerate their product development process.
# 6. **Architecture and Real Estate**: Generative AI can generate 3D models of buildings, homes, and real estate properties. This technology is being used by companies like Autodesk and Zillow to create immersive experiences for potential buyers and clients.
# 7. **Clinical Trials and Medical Research**: Generative AI can analyze large datasets from clinical trials, identifying patterns and insights that might be missed by human researchers. Companies like IBM Watson and Google Fit are using generative AI to accelerate medical research and trial design.
# 8. **Supply Chain Optimization**: Generative AI can analyze large datasets from supply chain operations, predicting demand, inventory levels, and shipping routes. Companies like Amazon and DHL are using generative AI to optimize their logistics operations.
# 9. **Customer Service Chatbots**: Generative AI can create personalized chatbot conversations that understand a customer's intent and respond accordingly. Companies like Domino's Pizza and Expedia are using generative AI-powered chatbots to enhance customer experiences.
# 10. **Data Analysis and Visualization**: Generative AI can analyze large datasets from various industries, generating insights and actionable recommendations for business decision-makers. Companies like Accenture and McKinsey are using generative AI to improve their data analysis and visualization capabilities.
#
# These are just a few examples of the many business applications of Generative AI. As the technology continues to evolve, we can expect to see even more innovative solutions across various industries.
